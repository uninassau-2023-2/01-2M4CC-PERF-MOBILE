# %% [markdown]
# <a href="https://colab.research.google.com/github/Diogjos/01-2M4CC-PERF-MOBILE/blob/main/Tabuada2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Tabuada de: "))
x = int(input("de quanto : "))
y = int(input("até quanto : "))
while x <= y:
  print(n ,"*", x , "=" , n * x)
  x = x + 1
# Out:
# Tabuada de: 2
# de quanto2
# até quanto8
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
